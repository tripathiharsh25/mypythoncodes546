# %% [raw]
# statastics

# %% [raw]
# data - any information we have is data , collection of information based on numbers observation measurment which can be utilized
# with calculation is data

# %% [raw]
# datum----singular
# data--- pural

# %% [raw]
# two type of data ,
# 1.> categogical qualitative -----
#     a. it have binomial data(yes/no/true/false) ,
#     b.it have nominal data(vertically red/green etc) ,
#     c.it have ordinal data
# 2.> numerical quantative ------
#     a.continuous data(two types - interval(zero not possible),ratio(zero possible) )
#     b.discrete countable

# %% [raw]
# the crude dataset is foundation data sciencen and it may be of different types structure(tabular) or unstructured(untabular)

# %% [raw]
# [10,20,30,25,20]=105/5=21
# mean is senstive to outliers
#
# [10,20,20,25,30]
# median =20(center)
#
# mode : number of time a same number appear

# %% [raw]
# hypothesis testing:
# null hypothesis:  :- sample data 70 claim 70
# alternative hypotheseis :-
