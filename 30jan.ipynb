# %%
a=99
b=90

# %%
a==b
# Out:
# False

# %%
c=67
d=67

# %%
c==d
# Out:
# True

# %%
a==b and c==d
# Out:
# False

# %%
a==b or c==d
# Out:
# True

# %%
age=19

# %%
if age>=18:
    print("eligible")
else:
    print("not eligible")
# Out:
# eligible

# %%
age1=int(input())
if age1>=18:
    print("eligible")
else:
    print("not eligible")
# Out:
#  12
# not eligible

# %%
age1=int(input())
if age1>=18 and age1<=30:
    print("adult")
elif age1>=31 and age1<=50:
    print("mature")
elif age1>=51:
    print("retired")
else:
    print("baby")
# Out:
#  38
# mature

# %%
a1= int(input())
if a1%2==0:
    print("even")
else:
    print("odd")
# Out:
#  45
# odd

# %%
choice=int(input())
match choice:
    case 1:
        print('one')
    case 2:
        print("two")
    case _:
        print("incalid")
# Out:
#  3
# incalid
