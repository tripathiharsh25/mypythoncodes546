# %%
y='2'
z='name'
print(y+z)
# Out:
# 2name

# %%
type(z)
# Out:
# str

# %%
print(y,z)
# Out:
# 2 name

# %%
y1=input()
z1=input()
print(y1+z1)
# Out:
#  hello
#  harsh
# helloharsh

# %%
y2=int(input())
z2=int(input())
print(y2+z2)
# Out:
#  23
#  34
# 57

# %%
y2=int(input())
z2=int(input())
print(y2+z2)
# Out:
#  ss
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 y2=int(input())
#       2 z2=int(input())
#       3 print(y2+z2)
#
# ValueError: invalid literal for int() with base 10: 'ss'

# %%
aa=5
bb="hello"
print(str(aa)+bb)
# Out:
# 5hello

# %%
type(aa)
# Out:
# int

# %%
aa=5
bb="hello"
print(aa+bb)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 aa=5
#       2 bb="hello"
# ----> 3 print(aa+bb)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
cc=3.44
type(cc)
# Out:
# float

# %%
dd=int(cc)
print(dd)
# Out:
# 3

# %%
cites= "landra" "mohali" "kharar"
print(cites)
# Out:
# landramohalikharar

# %%
cites= "landra","mohali","kharar"
print(cites)
# Out:
# ('landra', 'mohali', 'kharar')

# %%
cites= '''landra mohali kharar
jlpl'''
print(cites)
# Out:
# landra mohali kharar
# jlpl

# %%
cites= '''landra
mohali 
kharar'''
print(cites)
# Out:
# landra
# mohali
# kharar

# %%
cites= 'landra mohali kharar'
print(cites)
# Out:
# landra mohali kharar

# %%
cites2'king\queen\rookie\aman'
print(cites2)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\q'
# /tmp/xpython_42/1486976868.py:1: SyntaxWarning: invalid escape sequence '\q'
#   cites2='king\queen\rookie\aman'
# ookiemann

# %%
cites2=r'king\queen\rookie\aman'
print(cites2)
# Out:
# king\queen\rookie\aman

# %%
value='\u0927\u0928'
print(value)

#https://jrgraphix.net/r/Unicode/0900-097F
# Out:
# धन
