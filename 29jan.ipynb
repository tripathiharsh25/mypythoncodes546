# %%
list1 =['king','rookie','big','queen','pawn',2,3,4]
print(list1)
# Out:
# ['king', 'rookie', 'big', 'queen', 'pawn', 2, 3, 4]

# %%
list1.extend([5,6,7])

# %%
print(list1)
# Out:
# ['king', 'rookie', 'big', 'queen', 'pawn', 2, 3, 4, 5, 6, 7]

# %%
list1.pop(5)
print(list1)
# Out:
# ['king', 'rookie', 'big', 'queen', 'pawn', 3, 4, 5, 6, 7]

# %%
list1.insert(5,2)
print(list1)
# Out:
# ['king', 'rookie', 'big', 'queen', 'pawn', 2, 3, 4, 5, 6, 7]

# %%
list1.pop(7)
#list1.pop(9)
#list1.pop(10)
print(list1)
# Out:
# ['king', 'rookie', 'big', 'queen', 'pawn', 2, 3, 5, 6, 7]

# %%
list2=[11,12,13,14,15]

# %%
list3=["a",'b','c','d']

# %%
list3.insert(3,list2)
print(list3)
# Out:
# ['a', 'b', 'c', [11, 12, 13, 14, 15], 'd']

# %%
list3[3].append('roger')
print(list3)
# Out:
# ['a', 'b', 'c', [11, 12, 13, 14, 15, 'roger'], 'd']

# %%
name='harsh'
list3.append(name)
print(list3)
# Out:
# ['a', 'b', 'c', [11, 12, 13, 14, 15, 'roger'], 'd', 'harsh']

# %%
print(list3[3:])
# Out:
# [[11, 12, 13, 14, 15, 'roger'], 'd', 'harsh']

# %%
#tuple

# %%
tup=('king','queen','gagan',17,18,19)
type(tup)
# Out:
# tuple

# %%
tup[3]
# Out:
# 17

# %%
tup.count('queen')
# Out:
# 1

# %%
tup.index('queen')
# Out:
# 1

# %%
tup.index(17)
# Out:
# 3

# %%
x=list(tup)
print(x)
# Out:
# ['king', 'queen', 'gagan', 17, 18, 19]

# %%
type(x)
# Out:
# list

# %%
x=tuple(x)

# %%
type(x)
# Out:
# tuple

# %%
#dictionary

# %%
student={'name':'harsh','contact':345678}

# %%
print(student)
# Out:
# {'name': 'harsh', 'contact': 345678}

# %%
print(student['name'])
# Out:
# harsh

# %%
student['name']="triapthi"

# %%
print(student)
# Out:
# {'name': 'triapthi', 'contact': 345678}

# %%
student['address']='mohali'

# %%
print(student)
# Out:
# {'name': 'triapthi', 'contact': 345678, 'address': 'mohali'}

# %%
student.update({'name':'kamal','contact':7654321})

# %%
print(student)
# Out:
# {'name': 'kamal', 'contact': 7654321, 'address': 'mohali'}

# %%
student.pop('address')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 student.pop(address)
#
# NameError: name 'address' is not defined

# %%
student.pop('address')
# Out:
# 'mohali'

# %%
print(student)
# Out:
# {'name': 'kamal', 'contact': 7654321}

# %%
del student['name']

# %%
print(student)
# Out:
# {'contact': 7654321}

# %%
student.update({'subject':'data science','address':'mohali'})

# %%
student
# Out:
# {'contact': 7654321, 'subject': 'data science', 'address': 'mohali'}

# %%
print(student.get('contact2','value not found'))

#for getting graceful error
# Out:
# value not found

# %%
print(student.get('contact','value not found'))
# Out:
# 7654321

# %%
students={'student1':{'name':'jeet',
                      'rollno':6754347}
          ,'student2':{'name':'rajat',
                       'rollno':980434}}

# %%
print(students['student1']['name'])
# Out:
# jeet

# %%
print(len(students))
# Out:
# 2

# %%
students.keys()
# Out:
# dict_keys(['student1', 'student2'])

# %%
students.values()
# Out:
# dict_values([{'name': 'jeet', 'rollno': 6754347}, {'name': 'rajat', 'rollno': 980434}])

# %%
student.values()
# Out:
# dict_values([7654321, 'data science', 'mohali'])

# %%
'student3' in students
# Out:
# False

# %%
students.items()
# Out:
# dict_items([('student1', {'name': 'jeet', 'rollno': 6754347}), ('student2', {'name': 'rajat', 'rollno': 980434})])

# %%
'jeet' in students['student1']
# Out:
# False

# %%
'jeet' in students['student1'].values()
# Out:
# True

# %%
'mohali' in student
# Out:
# False

# %%
'mohali' in student.values()
# Out:
# True

# %%
#set

# %%
set1={'king','queen','roger','paul','queen'}

# %%
set1
# Out:
# {'king', 'paul', 'queen', 'roger'}

# %%
set1.pop()
# Out:
# 'king'

# %%
set1
# Out:
# {'paul', 'roger'}

# %%
set1.update({'king'})

# %%
set1
# Out:
# {'king', 'paul', 'roger'}

# %%
set1.update('king')

# %%
set1
# Out:
# {'g', 'i', 'k', 'king', 'n', 'paul', 'roger'}

# %%
listx=set(list1)

# %%
listx
# Out:
# {2, 3, 5, 6, 7, 'big', 'king', 'pawn', 'queen', 'rookie'}

# %%
#string meathod

# %%
name1='king'

# %%
print(name1.upper())
# Out:
# KING

# %%
name2='KING'

# %%
print(name2.lower())
# Out:
# king

# %%
name3=input().lower()
# Out:
#  RAJAT

# %%
name3
# Out:
# 'rajat'

# %%
name1.capitalize()
# Out:
# 'King'

# %%
sentence='    i am the student   '
print(sentence)
# Out:
#     i am the student

# %%
print(sentence.strip())
# Out:
# i am the student

# %%
sentence=sentence.replace("student","king")

# %%
print(sentence.strip())
# Out:
# i am the king

# %%
sentence
print(sentence.split())
# Out:
# ['i', 'am', 'the', 'king']

# %%
word='king'

# %% [raw]
# word.isdigit()
