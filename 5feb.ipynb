# %% [markdown]
# object oriented programming

# %% [markdown]
# 1 encapsulation
# 2 inheritence
# 3 polymorphism
# 4 abstraction

# %%
class phone:
    x=6
    y=7

# %%
obj=phone()

# %%
obj.x
# Out:
# 6

# %%
x=66

# %%
obj.x
# Out:
# 6

# %%
type(obj)
# Out:
# __main__.phone

# %%
type(obj.x)
# Out:
# int

# %%
x
# Out:
# 66

# %%
obj.x*obj.y
# Out:
# 42

# %%
class calc:
    def add(self,a,b):
        print(a+b)
    def sub(self,a,b):
        print(a-b)

# %%
abc=calc()

# %%
abc.add(4,5)
# Out:
# 9

# %%
class king:
    def __init__(self,name):
        self.name = name
        print('code register on name ',self.name)
        print('use below fuction. \n1.add \n2.sub \n3.mul')
    def add(self,a,b):
        print(a+b)
    def sub(self,a,b):
        print(a-b)
    def mult(self,a,b):
        print(a*b)
    def info(self):
        print('this code belongs to ',self.name)

# %%
aa=king("harsh")
# Out:
# code register on name  harsh
# use below fuction.
# 1.add
# 2.sub
# 3.mul

# %%
class parent:
    def display(self):
        print('i am parent')

# %%
class child(parent):
    def display2(self):
        print('i am child ')

# %%
obj2=child()

# %%
obj2.display2()
# Out:
# i am child

# %%
obj2.display()
# Out:
# i am parent

# %%
class parent2:
    def display(self):
        print('i am parent2')

# %%
zx= super()

# %%
class A:
    def add(self,a,b):
        print(a+b)

# %%
class B(A):
    def sub(self,a,b):
        print(a-b)

# %%
class C(B):
    def mul(self,a,b):
        print(a*b)

# %%
class AA:
    def display12(self):
        print('i am AA')

# %%
class BB(AA):
    def display13(self):
        print('i am BB')

# %%
class CC(BB):
    def display14(self):
        print('i am CC')

# %%
class ABC(C,CC):
    def display15(self):
        print('i am all')

# %%
kk=ABC()

# %%
kk.display13()
# Out:
# i am BB

# %%
class bankaccount:
    def __init__(self, name, balance=0):
        self.name=name
        self.balance=balance
        self.transactions=[]
        self.transactions.append(f"Name:- {name}")
        self.transactions.append(f"opening balance= {balance}")
        print('welcome to our bank')
    def deposit(self, amount):
        if amount >0:
            self.balance+=amount
            self.transactions.append(f"deposit amount is {amount} and balance is {self.balance}")
        else:
            print('amount must be in positive')
    def withdrawl(self, amount):
        if amount<self.balance:
            self.balance-=amount
        else:
            print('insufficient balance')
        self.transactions.append(f"withdraw amount:- {amount} balance= {self.balance}")
    def viewbalance(self):
        print(f"{self.name}, {self.balance}")
    def transaction(self):
        for i in self.transactions:
            print(i)

# %%
harsh=bankaccount('harsh', 500)
# Out:
# welcome to our bank

# %%
harsh.viewbalance()
# Out:
# harsh, 500

# %%
harsh.deposit(-580)
# Out:
# amount must be in positive

# %%
harsh.deposit(859)

# %%
harsh.transaction()
# Out:
# Name:- harsh
# opening balance= 500
# deposit amount is 859 and balance is 1359
